# %% [markdown]
# # Libraries and global variables

# %%
from pathlib import Path
import json
import sys
from typing import Optional
import time
import copy

import numpy as np
import pandas as pd
from PIL import Image

import torch
import torch.utils.data as data
import torchvision
import torchvision.transforms as T
import torchvision.transforms.functional as TF
from torchvision.models.detection import (
    fasterrcnn_resnet50_fpn_v2,
    FasterRCNN_ResNet50_FPN_V2_Weights
)
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# %%
print(sys.version) # Python version
print(torch.__version__) # PyTorch version
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# 2.10.0+cu128

# %% [markdown]
# ## Colab folders

# %%
#from google.colab import drive
#drive.mount("/content/drive")

# %%
#!cp -r "/content/drive/MyDrive/Work/10 Foodbegood/project_gn_food_estimator_v1" "/content/project_gn_food_estimator_v1"

# %% [markdown]
# ## Directory layout & paths

# %%
PLATFORM = "kaggle" # "colab", "kaggle", "local"

if PLATFORM == "colab":
    ROOT_IN = Path("/content/project_gn_food_estimator_v1")
    ROOT_OUT = ROOT_IN
elif PLATFORM == "kaggle":
    ROOT_IN = Path("/kaggle/input/datasets/matarauj/project-gn-data/")
    ROOT_OUT = Path("/kaggle/working/")
else:
    ROOT = Path(".").resolve()

# %%
####################
# INPUT
####################
DATA_DIR      = ROOT_IN / "data"
RAW_DIR       = DATA_DIR / "raw"
PROCESSED_DIR = DATA_DIR / "processed"
EXPORTS_DIR   = DATA_DIR / "exports"

# Labels file
COCO_MODEL1_JSON = EXPORTS_DIR / "model1_detection_v3.json"

####################
# OUTPUT
####################
MODELS_DIR    = ROOT_OUT / "models"
TRAINING_DIR  = ROOT_OUT / "training"
LOGS_DIR      = TRAINING_DIR / "logs"

# Model checkpoint path
MODEL1_PATH = MODELS_DIR / "model1_detector.pth"

# Label mapping alongside the weights
label_map_path = MODELS_DIR / "model1_label_map.json"

# %%
def setup_directories():
    """
    Ensure output directories exist.
    """
    MODELS_DIR.mkdir(parents = True, exist_ok = True)
    LOGS_DIR.mkdir(parents = True, exist_ok = True)
    print(f"[Setup] Models dir: {MODELS_DIR}")
    print(f"[Setup] Logs dir : {LOGS_DIR}")

# %%
setup_directories()
# Out:
# [Setup] Models dir: /kaggle/working/models
# [Setup] Logs dir : /kaggle/working/training/logs

# %% [markdown]
# ## Parameters

# %%
# Dataset split ratios
SPLIT_TRAIN = 0.80
SPLIT_VAL   = 0.10
SPLIT_TEST  = 0.10
RANDOM_SEED = 42

# %%
# Class labels — index 0 is ALWAYS background in torchvision detection models.
# Your actual classes start at index 1.
MODEL1_CLASSES = ["small_container", "large_container"]
NUM_CLASSES = len(MODEL1_CLASSES) + 1 # +1 for background

# %%
# Image pre-processing
IMAGE_SIZE = 512

# %% [markdown]
# ## Training hyperparameters

# %%
# Model #1 — ResNet-50, object detection head
MODEL1_BATCH_SIZE      = 4

MODEL1_EPOCHS_FROZEN   = 8       # Phase 1: RPN + head only
MODEL1_EPOCHS_UNFROZEN = 200     # Phase 2: full network fine-tune

MODEL1_LR_FROZEN       = 1e-3
MODEL1_LR_UNFROZEN     = 1e-4

MODEL1_WEIGHT_DECAY    = 5e-4
MODEL1_MIXED_PREC      = True    # fp16

EARLY_STOPPING_PATIENCE = 15

# %%
def check_gpu():
    """
    Report GPU availability and VRAM.
    """
    if torch.cuda.is_available():
        gpu_name = torch.cuda.get_device_name(0)
        vram_gb = torch.cuda.get_device_properties(0).total_memory / 1e9

        print(f"[GPU] {gpu_name} - {vram_gb:.1f} GB VRAM")

        if vram_gb < 14.0:
            print(
                f"[GPU] WARNING: Less than 14 GB VRAM detected. "
                f"Consider reducing MODEL1_BATCH_SIZE if you hit OOM."
                f"Currently {MODEL1_BATCH_SIZE}."
            )
    else:
        print("[GPU] No CUDA device found - training will run on CPU.")
    return "cuda" if torch.cuda.is_available() else "cpu"

# %%
DEVICE = check_gpu()
# Out:
# [GPU] Tesla T4 - 15.6 GB VRAM

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Data augmentation pipeline

# %% [markdown]
# Augmentationt pipelines for Model #1. Each function returns a fastai Transform list that can be passed directly to a DataBlock or DataLoaders.
#
# Relevant augmentations:
# - brightness
# - rotation
# - blur
# - scaling
# - flipping
# - contrast
#
# Design note: top-down food photography has specific characteristics:
# - Rotation up to ±30° (user hand angle variation)
# - Moderate blur simulates slight camera shake at distance
# - Brightness / contrast variation simulates kitchen lighting changes

# %% [markdown]
# # Loading data

# %% [markdown]
# Dataset loader for:
# - Object detection (COCO JSON bounding-box annotations)
#
# Label Studio COCO export format assumptions:
# - Detection export  : standard COCO format with "images", "annotations", "categories" keys. Each annotation has bbox in [x_min, y_min, width, height] format.
#
# Split strategy:
# - Splits are performed at the image level (not annotation level) to avoid data leakage between train / val / test.
# - Ratios: 80 / 10 / 10
# - Random seed is fixed for reproducibility.

# %% [markdown]
# ## COCO JSON helpers

# %%
def load_coco_json(json_path: Path) -> dict:
    """
    Load and validate a COCO JSON file exported from Label Studio.
    """
    if not json_path.exists():
        raise FileNotFoundError(
            f"COCO annotation file not found: {json_path}\n"
            f"Export your Label Studio project as COCO JSON and place it at "
            f"the path defined in {COCO_MODEL1_JSON}."
        )
    with open(json_path, "r") as f:
        data = json.load(f)

    required_keys = {"images", "annotations", "categories"}

    if not required_keys.issubset(data.keys()):
        raise ValueError(
            f"COCO JSON at {json_path} is missing keys: "
            f"{required_keys - data.keys()}"
        )
    return data



def split_image_ids(
        image_ids: list,
        train_ratio: float = SPLIT_TRAIN,
        val_ratio: float = SPLIT_VAL,
        seed: int = RANDOM_SEED
    ) -> tuple:
    """
    Randomly split a list of image IDs into train / val / test sets.

    Returns:
        tuple[set, set, set]
            (train_ids, val_ids, test_ids)
    """
    rng = np.random.default_rng(seed)
    ids = np.array(image_ids)
    rng.shuffle(ids)

    n = len(ids)
    n_train = int(n * train_ratio)
    n_val = int(n * val_ratio)

    train_ids = set(ids[:n_train].tolist())
    val_ids = set(ids[n_train:n_train + n_val].tolist())
    test_ids = set(ids[n_train + n_val:].tolist())

    print(f"Split -> train: {len(train_ids)} | val: {len(val_ids)} | test: {len(test_ids)} images")
    return train_ids, val_ids, test_ids



def build_annotation_df(coco: dict, image_dir: Path) -> tuple:
    """
    Parse a COCO dict into a flat DataFrame with one row per annotation.

    bbox is converted from COCO format [x, y, w, h] to Pascal VOC
    [x_min, y_min, x_max, y_max] as required by torchvision.

    Returns (full_df, lable_to_idx) where label_to_idx maps class name
    to the torchvision label index (1-based, 0 = background).
    """
    # Category mapping - torchvision needs 1-based integer labels
    # Sort by category if for deterministic ordering
    cats_sorted = sorted(coco["categories"], key = lambda c: c["id"])
    label_to_idx = {cat["name"]: i+1 for i, cat in enumerate(cats_sorted)}
    print(f"Label -> index mapping: {label_to_idx}")

    # Warn if COCO labels differ from MODEL1_CLASSES
    coco_labels = set(label_to_idx.keys())
    cfg_labels = set(MODEL1_CLASSES)
    if coco_labels != cfg_labels:
        print(f"WARNING: COCO labels {coco_labels} differ from "
            f"MODEL1_CLASSES {cfg_labels}. Update MODEL1_CLASSES if needed.")

    # Image id -> cleaned filename
    id_to_file = {
        img["id"]: Path(img["file_name"].replace("\\", "/")).name.split("-", 1)[-1]
        for img in coco["images"]
    }

    all_image_ids = list(id_to_file.keys())
    print(f"Total images: {len(all_image_ids)}")

    train_ids, val_ids, test_ids = split_image_ids(all_image_ids)

    rows = []
    for ann in coco["annotations"]:
        img_id = ann["image_id"]
        filename = id_to_file[img_id]
        x, y, w, h = ann["bbox"]
        label_name = {cat["id"]: cat["name"] for cat in coco["categories"]}[
            ann["category_id"]
        ]
        split = (
            "train" if img_id in train_ids else
            "valid" if img_id in val_ids else
            "test"
        )
        rows.append({
            "image_path": str(image_dir / filename),
            "x_min": float(x),
            "y_min": float(y),
            "x_max": float(x + w),
            "y_max": float(y + h),
            "label": label_name,
            "label_idx": label_to_idx[label_name],
            "split": split
        })

    return pd.DataFrame(rows), label_to_idx

# %% [markdown]
# ## Dataset

# %%
class GNDetectionDataset(data.Dataset):
    """
    PyTorch Dataset for GN container detection.

    Each item returns:
        image: FloatTensor [3, H, W], pixel values in [0, 1]
        target: dict with keys:
            boxes : FloatTensor [N, 4] - Pascal VOC format
            labels : Int64Tensor [N] - 1-based class indices
            image_id : Int64Tensor [1]
    """
    def __init__(self, df: pd.DataFrame, transforms = None):
        """
        Parameters
            df : pd.DataFrame
                Annotation DataFrame with columns:
                image_path, x_min, y_min, x_max, y_max, label_idx
            transforms : callable, optional
                torchvision transform applied to (image, target) pairs.
        """
        # Group by image so each __getitem__ returns all boxes for one image
        self.records = []
        for img_path, grp in df.groupby("image_path"):
            self.records.append({
                "image_path": img_path,
                "boxes": grp[["x_min", "y_min", "x_max", "y_max"]].values,
                "labels": grp["label_idx"].values
            })
        self.transforms = transforms


    def __len__(self):
        return len(self.records)


    def __getitem__(self, idx):
        rec = self.records[idx]
        image = Image.open(rec["image_path"]).convert("RGB")
        image = TF.to_tensor(image) # FloatTensor [3, H, W] on [0, 1]

        boxes = torch.as_tensor(rec["boxes"], dtype = torch.float32)
        labels = torch.as_tensor(rec["labels"], dtype = torch.int64)

        target = {
            "boxes": boxes,
            "labels": labels,
            "image_ids": torch.tensor([idx])
        }
        if self.transforms:
            image, target = self.transforms(image, target)

        return image, target



def collate_fn(batch):
    """
    Custom collate: Faster R-CNN expects a list of (image, target) pairs,
    not a stacked tensor, because images can have different numbers of boxes.
    """
    return tuple(zip(*batch))

# %% [markdown]
# ## Transforms

# %%
class Compose:
    """
    Chain multiple (image, target) transforms.
    """
    def __init__(self, transforms):
        self.transforms = transforms


    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)

        return image, target



class RandomHorizontalFlip:
    """
    Horizontally flip image and adjust bounding boxes.
    """
    def __init__(self, prob = 0.5):
        self.prob = prob


    def __call__(self, image, target):
        if torch.rand(1) < self.prob:
            _, h, w = image.shape # C, H, W
            image = TF.hflip(image)
            boxes = target["boxes"].clone()
            boxes[:, [0, 2]] = w - boxes[:, [2,0]]
            target["boxes"] = boxes

        return image, target



class ResizeLongestEdge:
    """
    Resize so that the longest edge equals 'size', preserving aspect ratio.
    """
    def __init__(self, size = IMAGE_SIZE):
        self.size = size


    def __call__(self, image, target):
        _, h, w = image.shape
        scale = self.size / max(h, w)
        new_h = int(h * scale)
        new_w = int(w * scale)
        image = TF.resize(image, [new_h, new_w])

        if target is not None and "boxes" in target:
            target["boxes"] = target["boxes"] * scale

        return image, target


class ColorJitter:
    """
    Apply brightness and contrast jitter.
    """
    def __init__(self, brightness = 0.3, contrast = 0.3):
        self.jitter = T.ColorJitter(brightness = brightness, contrast = contrast)


    def __call__(self, image, target):
        image = self.jitter(image)
        return image, target


class RandomRotation:
    def __init__(self, degrees=30, prob=0.5):
        self.degrees = degrees
        self.prob = prob

    def __call__(self, image, target):
        if torch.rand(1) < self.prob:
            angle = float(torch.empty(1).uniform_(-self.degrees, self.degrees))

            _, h, w = image.shape
            image = TF.rotate(image, angle)

            # --- Rotate bounding boxes ---
            boxes = target["boxes"]
            cx, cy = w / 2, h / 2

            new_boxes = []
            for box in boxes:
                x_min, y_min, x_max, y_max = box

                corners = torch.tensor([
                    [x_min, y_min],
                    [x_max, y_min],
                    [x_max, y_max],
                    [x_min, y_max]
                ])

                # Translate to center
                corners[:, 0] -= cx
                corners[:, 1] -= cy

                # Rotation matrix
                theta = -angle * np.pi / 180
                rot = torch.tensor([
                    [np.cos(theta), -np.sin(theta)],
                    [np.sin(theta),  np.cos(theta)]
                ])

                corners = corners @ rot.T

                # Translate back
                corners[:, 0] += cx
                corners[:, 1] += cy

                x_coords = corners[:, 0]
                y_coords = corners[:, 1]

                new_boxes.append([
                    x_coords.min(),
                    y_coords.min(),
                    x_coords.max(),
                    y_coords.max()
                ])

            target["boxes"] = torch.stack([torch.tensor(b) for b in new_boxes])

        return image, target


class RandomScale:
    def __init__(self, scale_range=(0.8, 1.2), prob=0.5):
        self.scale_range = scale_range
        self.prob = prob

    def __call__(self, image, target):
        if torch.rand(1) < self.prob:
            scale = float(torch.empty(1).uniform_(*self.scale_range))

            _, h, w = image.shape
            new_h, new_w = int(h * scale), int(w * scale)

            image = TF.resize(image, [new_h, new_w])

            target["boxes"] = target["boxes"] * scale

        return image, target


class RandomBlur:
    def __init__(self, kernel_size=5, prob=0.3):
        self.kernel_size = kernel_size
        self.prob = prob

    def __call__(self, image, target):
        if torch.rand(1) < self.prob:
            image = TF.gaussian_blur(image, kernel_size=self.kernel_size)
        return image, target


class RandomVerticalFlip:
    def __init__(self, prob=0.2):
        self.prob = prob

    def __call__(self, image, target):
        if torch.rand(1) < self.prob:
            _, h, w = image.shape
            image = TF.vflip(image)

            boxes = target["boxes"].clone()
            boxes[:, [1, 3]] = h - boxes[:, [3, 1]]
            target["boxes"] = boxes

        return image, target


def get_train_transforms():
    return Compose([
        ResizeLongestEdge(IMAGE_SIZE),
        
        RandomHorizontalFlip(prob = 0.5),
        #RandomVerticalFlip(prob=0.1),

        #RandomRotation(degrees=20, prob=0.4),
        #RandomScale(scale_range=(0.85, 1.15), prob=0.1),
        
        ColorJitter(brightness = 0.2, contrast = 0.2)
        #RandomBlur(kernel_size=5, prob=0.2)
    ])


def get_val_transforms():
    return Compose([
        ResizeLongestEdge(IMAGE_SIZE)
    ])

# %% [markdown]
# ## Build DataLoaders

# %%
print("[Data] Loading COCO annotations...")
coco = load_coco_json(COCO_MODEL1_JSON)
full_df, label_to_idx = build_annotation_df(coco, RAW_DIR)

train_val_df = full_df[full_df["split"] != "test"].copy()
test_df = full_df[full_df["split"] == "test"].copy()

train_df = train_val_df[train_val_df["split"] == "train"]
val_df = train_val_df[train_val_df["split"] == "valid"]

print(f"Annotation rows - train: {len(train_df)} |"
    f"val: {len(val_df)} | test: {len(test_df)}")

# Save test split for post-training evaluation
test_csv_path = LOGS_DIR / "model1_test_split.csv"
test_df.to_csv(test_csv_path, index = False)
print(f"Test split saved: {test_csv_path}")
# Out:
# [Data] Loading COCO annotations...
# Label -> index mapping: {'large_container': 1, 'small_container': 2}
# Total images: 200
# Split -> train: 160 | val: 20 | test: 20 images
# Annotation rows - train: 160 |val: 20 | test: 20
# Test split saved: /kaggle/working/training/logs/model1_test_split.csv

# %%
train_dataset = GNDetectionDataset(train_df, transforms=get_train_transforms())
val_dataset = GNDetectionDataset(val_df, transforms=get_val_transforms())

train_loader = data.DataLoader(
    train_dataset,
    batch_size = MODEL1_BATCH_SIZE,
    shuffle = True,
    num_workers = 2,
    collate_fn = collate_fn,
    pin_memory = (DEVICE == "cuda")
)
val_loader = data.DataLoader(
    val_dataset,
    batch_size = MODEL1_BATCH_SIZE,
    shuffle = False,
    num_workers = 2,
    collate_fn = collate_fn,
    pin_memory = (DEVICE == "cuda")
)

print(f"Train batches: {len(train_loader)} | Val batches: {len(val_loader)}")
# Out:
# Train batches: 40 | Val batches: 5

# %% [markdown]
# # Model

# %%
def build_model(num_classes: int) -> torch.nn.Module:
    """
    Load Faster R-CNN ResNet-50 FPN v2 with ImageNet-pretrained weights,
    then replace the classification head to match our number of classes.

    num_classes includes background(e.g. 3 = background + small + large).
    """
    weights = FasterRCNN_ResNet50_FPN_V2_Weights.DEFAULT
    model = fasterrcnn_resnet50_fpn_v2(weights = weights)

    # Replace the box predictor head - this is the standard torchvision pattern
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    return model

# %%
print(f"[Model] Building Faster R-CNN ResNet-50 FPN v2"
    f"(num_classes = {NUM_CLASSES} including background).")

model = build_model(NUM_CLASSES)
model.to(DEVICE)
print("Model ready.")
# Out:
# [Model] Building Faster R-CNN ResNet-50 FPN v2(num_classes = 3 including background).
# Model ready.

# %% [markdown]
# ## Freeze / unfreeze helpers

# %%
def freeze_backbone(model: torch.nn.Module):
    """
    Freeze all backbone and FPN parameters.
    Only the RPN and ROI heads will be trained in Phase 1.
    """
    for name, param in model.named_parameters():
        if "backbone" in name or "fpn" in name:
            param.requires_grad = False
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)

    print(f"Backbone frozen — trainable parameters: {trainable:,}")


def unfreeze_all(model: torch.nn.Module):
    """
    Unfreeze all parameters for Phase 2 fine-tuning.
    """
    for param in model.parameters():
        param.requires_grad = True
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)

    print(f"All layers unfrozen — trainable parameters: {trainable:,}")


def get_optimizer_phase1(model, lr = MODEL1_LR_FROZEN, wd = MODEL1_WEIGHT_DECAY):
    """
    Optimise only trainable (non-frozen) parameters.
    """
    params = [p for p in model.parameters() if p.requires_grad]

    return torch.optim.SGD(params, lr = lr, momentum = 0.9, weight_decay = wd)


def get_optimizer_phase2(model, lr = MODEL1_LR_UNFROZEN, wd = MODEL1_WEIGHT_DECAY):
    """
    Discriminative learning rates for Phase 2:
    backbone gets lr/10, heads get full lr.
    """
    backbone_params = [
        p for n, p in model.named_parameters()
        if ("backbone" in n or "fpn" in n) and p.requires_grad
    ]
    head_params = [
        p for n, p in model.named_parameters()
        if ("backbone" not in n and "fpn" not in n) and p.requires_grad
    ]

    return torch.optim.SGD(
        [
            {"params": backbone_params, "lr": lr / 10},
            {"params": head_params,     "lr": lr},
        ],
        momentum = 0.9,
        weight_decay = wd)

# %% [markdown]
# # Training loop

# %%
def train_one_epoch(model, loader, optimizer, device, scaler = None, epoch = 0):
    """
    One training epoch.

    Faster R-CNN returns a dict of losses when called in training mode:
        loss_classifier   — RoI classification loss
        loss_box_reg      — RoI bounding box regression loss
        loss_objectness   — RPN objectness loss
        loss_rpn_box_reg  — RPN box regression loss
    Total loss is their sum.
    """
    model.train()
    total_loss = 0.0

    for i, (images, targets) in enumerate(loader):
        images  = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        optimizer.zero_grad()

        if scaler is not None:
            with torch.cuda.amp.autocast():
                loss_dict = model(images, targets)
                loss = sum(loss_dict.values())
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
        else:
            loss_dict = model(images, targets)
            loss = sum(loss_dict.values())
            loss.backward()
            optimizer.step()

        total_loss += loss.item()

        if (i + 1) % 5 == 0 or (i + 1) == len(loader):
            print(f"  Epoch {epoch+1} [{i+1}/{len(loader)}]  "
                  f"loss: {loss.item():.4f}  "
                  f"(cls: {loss_dict['loss_classifier'].item():.3f}  "
                  f"box: {loss_dict['loss_box_reg'].item():.3f}  "
                  f"rpn: {loss_dict['loss_objectness'].item():.3f})")

    return total_loss / len(loader)


@torch.no_grad()
def evaluate_one_epoch(model, loader, device):
    """
    Validation epoch.

    Note: Faster R-CNN only returns losses when targets are supplied AND the
    model is in training mode. To get validation loss we temporarily switch
    to train mode — this is the standard torchvision pattern for monitoring
    validation loss without running full COCO mAP evaluation (which requires
    the pycocotools package).
    """
    model.train()   # needed to get loss dict — see note above
    total_loss = 0.0
    with torch.no_grad():
        for images, targets in loader:
            images  = [img.to(device) for img in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
            loss_dict  = model(images, targets)
            total_loss += sum(loss_dict.values()).item()
    model.eval()

    return total_loss / len(loader)


def run_training(
    model,
    train_loader,
    val_loader,
    optimizer,
    scheduler,
    n_epochs,
    device,
    scaler = None,
    phase_label = "Phase"
):
    """
    Training loop with early stopping and best-model checkpointing.

    Returns the best validation loss achieved.
    """
    best_val_loss  = float("inf")
    best_weights   = copy.deepcopy(model.state_dict())
    patience_count = 0
    log_rows       = []

    for epoch in range(n_epochs):
        t0 = time.time()

        train_loss = train_one_epoch(
            model, train_loader, optimizer, device, scaler, epoch
        )
        val_loss = evaluate_one_epoch(model, val_loader, device)

        if scheduler is not None:
            scheduler.step()

        elapsed = time.time() - t0
        print(f"[{phase_label}] Epoch {epoch+1}/{n_epochs}  "
              f"train_loss: {train_loss:.4f}  val_loss: {val_loss:.4f}  "
              f"({elapsed:.0f}s)")

        log_rows.append({
            "phase": phase_label, "epoch": epoch + 1,
            "train_loss": train_loss, "val_loss": val_loss,
        })

        # Best model checkpoint
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_weights  = copy.deepcopy(model.state_dict())
            patience_count = 0
            print(f"  ✓ New best val_loss: {best_val_loss:.4f} — checkpoint saved")
        else:
            patience_count += 1
            print(f"  No improvement ({patience_count}/{EARLY_STOPPING_PATIENCE})")
            if patience_count >= EARLY_STOPPING_PATIENCE:
                print(f"  Early stopping triggered after epoch {epoch+1}.")
                break

    # Restore best weights
    model.load_state_dict(best_weights)

    return best_val_loss, pd.DataFrame(log_rows)

# %% [markdown]
# ## Mixed precision scaler

# %%
scaler = None
if MODEL1_MIXED_PREC and DEVICE == "cuda":
    scaler = torch.cuda.amp.GradScaler()
    print("\n[Training] Mixed precision (fp16) — ENABLED")
else:
    print("\n[Training] Mixed precision — DISABLED")
# Out:
# [Training] Mixed precision (fp16) — ENABLED
# /tmp/ipykernel_159/2445419710.py:3: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()

# %% [markdown]
# ## Phase 1 - frozen backbone

# %%
print(f"\n{'='*60}")
print(f"  Phase 1 — frozen backbone ({MODEL1_EPOCHS_FROZEN} epochs)")
print(f"{'='*60}")

freeze_backbone(model)
optimizer_p1 = get_optimizer_phase1(model)
scheduler_p1 = torch.optim.lr_scheduler.OneCycleLR(
    optimizer_p1,
    max_lr = MODEL1_LR_FROZEN,
    steps_per_epoch = len(train_loader),
    epochs = MODEL1_EPOCHS_FROZEN,
    pct_start = 0.3
)

best_loss_p1, log_p1 = run_training(
    model, train_loader, val_loader,
    optimizer_p1, scheduler_p1,
    MODEL1_EPOCHS_FROZEN, DEVICE, scaler,
    phase_label = "Phase1",
)

print(f"\nPhase 1 complete — best val_loss: {best_loss_p1:.4f}")
# Out:
# ============================================================
#   Phase 1 — frozen backbone (5 epochs)
# ============================================================
# Backbone frozen — trainable parameters: 16,406,814
# /tmp/ipykernel_159/955033620.py:22: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
#   Epoch 1 [5/40]  loss: 1.4305  (cls: 1.282  box: 0.136  rpn: 0.009)
#   Epoch 1 [10/40]  loss: 1.2998  (cls: 1.164  box: 0.118  rpn: 0.017)
#   Epoch 1 [15/40]  loss: 1.1237  (cls: 1.000  box: 0.104  rpn: 0.019)
#   Epoch 1 [20/40]  loss: 0.9704  (cls: 0.822  box: 0.111  rpn: 0.034)
#   Epoch 4 [40/40]  loss: 0.2420  (cls: 0.109  box: 0.119  rpn: 0.012)
# [Phase1] Epoch 4/5  train_loss: 0.2392  val_loss: 0.2339  (31s)
#   ✓ New best val_loss: 0.2339 — checkpoint saved
#   Epoch 5 [5/40]  loss: 0.2593  (cls: 0.116  box: 0.111  rpn: 0.031)
#   Epoch 5 [10/40]  loss: 0.2227  (cls: 0.102  box: 0.102  rpn: 0.018)
#   Epoch 5 [15/40]  loss: 0.2250  (cls: 0.100  box: 0.103  rpn: 0.017)
#   Epoch 5 [20/40]  loss: 0.2457  (cls: 0.114  box: 0.108  rpn: 0.022)
#   Epoch 5 [25/40]  loss: 0.1854  (cls: 0.076  box: 0.071  rpn: 0.037)
#   Epoch 5 [30/40]  loss: 0.2234  (cls: 0.091  box: 0.093  rpn: 0.037)
#   Epoch 5 [35/40]  loss: 0.2202  (cls: 0.094  box: 0.103  rpn: 0.011)
#   Epoch 5 [40/40]  loss: 0.2324  (cls: 0.102  box: 0.113  rpn: 0.014)
# [Phase1] Epoch 5/5  train_loss: 0.2282  val_loss: 0.2239  (32s)
#   ✓ New best val_loss: 0.2239 — checkpoint saved
#
# Phase 1 complete — best val_loss: 0.2239

# %% [markdown]
# ## Phase 2 - full fine-tune

# %%
print(f"\n{'='*60}")
print(f"  Phase 2 — full fine-tune ({MODEL1_EPOCHS_UNFROZEN} epochs)")
print(f"{'='*60}")

unfreeze_all(model)
optimizer_p2 = get_optimizer_phase2(model)
scheduler_p2 = torch.optim.lr_scheduler.OneCycleLR(
    optimizer_p2,
    max_lr = [MODEL1_LR_UNFROZEN / 10, MODEL1_LR_UNFROZEN],
    steps_per_epoch = len(train_loader),
    epochs = MODEL1_EPOCHS_UNFROZEN,
    pct_start = 0.3,
)

best_loss_p2, log_p2 = run_training(
    model, train_loader, val_loader,
    optimizer_p2, scheduler_p2,
    MODEL1_EPOCHS_UNFROZEN, DEVICE, scaler,
    phase_label = "Phase2",
)

print(f"\nPhase 2 complete — best val_loss: {best_loss_p2:.4f}")
# Out:
# ============================================================
#   Phase 2 — full fine-tune (50 epochs)
# ============================================================
# All layers unfrozen — trainable parameters: 43,261,278
# /tmp/ipykernel_159/955033620.py:22: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
#   Epoch 1 [5/40]  loss: 0.2315  (cls: 0.096  box: 0.112  rpn: 0.021)
#   Epoch 1 [10/40]  loss: 0.2290  (cls: 0.102  box: 0.103  rpn: 0.021)
#   Epoch 1 [15/40]  loss: 0.1892  (cls: 0.082  box: 0.076  rpn: 0.027)
#   Epoch 1 [20/40]  loss: 0.2192  (cls: 0.100  box: 0.102  rpn: 0.015)
#   Epoch 1 [25/40]  loss: 0.2128  (cls: 0.091  box: 0.096  rpn: 0.023)
#   Epoch 1 [30/40]  loss: 0.1825  (cls: 0.076  box: 0.077  rpn: 0.024)
#   Epoch 1 [35/40]  loss: 0.2433  (cls: 0.105  box: 0.113  rpn: 0.024)
#   Epoch 1 [40/40]  loss: 0.2120  (cls: 0.093  box: 0.100  rpn: 0.015)
# [Phase2] Epoch 1/50  train_loss: 0.2216  val_loss: 0.2263  (37s)
#   No improvement (4/10)
#   Epoch 49 [5/40]  loss: 0.1869  (cls: 0.073  box: 0.093  rpn: 0.015)
#   Epoch 49 [10/40]  loss: 0.1996  (cls: 0.081  box: 0.106  rpn: 0.011)
#   Epoch 49 [15/40]  loss: 0.1707  (cls: 0.067  box: 0.088  rpn: 0.013)
#   Epoch 49 [20/40]  loss: 0.2049  (cls: 0.081  box: 0.101  rpn: 0.021)
#   Epoch 49 [25/40]  loss: 0.2327  (cls: 0.091  box: 0.125  rpn: 0.015)
#   Epoch 49 [30/40]  loss: 0.1987  (cls: 0.074  box: 0.087  rpn: 0.035)
#   Epoch 49 [35/40]  loss: 0.2210  (cls: 0.088  box: 0.120  rpn: 0.010)
#   Epoch 49 [40/40]  loss: 0.2078  (cls: 0.076  box: 0.098  rpn: 0.031)
# [Phase2] Epoch 49/50  train_loss: 0.1969  val_loss: 0.1895  (37s)
#   No improvement (5/10)
#   Epoch 50 [5/40]  loss: 0.1910  (cls: 0.073  box: 0.088  rpn: 0.025)
#   Epoch 50 [10/40]  loss: 0.2035  (cls: 0.086  box: 0.096  rpn: 0.020)
#   Epoch 50 [15/40]  loss: 0.2002  (cls: 0.076  box: 0.095  rpn: 0.026)
#   Epoch 50 [20/40]  loss: 0.2103  (cls: 0.089  box: 0.110  rpn: 0.010)
#   Epoch 50 [25/40]  loss: 0.1925  (cls: 0.078  box: 0.104  rpn: 0.008)
#   Epoch 50 [30/40]  loss: 0.1952  (cls: 0.073  box: 0.097  rpn: 0.024)
#   Epoch 50 [35/40]  loss: 0.1884  (cls: 0.068  box: 0.088  rpn: 0.028)
#   Epoch 50 [40/40]  loss: 0.2075  (cls: 0.081  box: 0.106  rpn: 0.019)
# [Phase2] Epoch 50/50  train_loss: 0.1945  val_loss: 0.1841  (37s)
#   ✓ New best val_loss: 0.1841 — checkpoint saved
#
# Phase 2 complete — best val_loss: 0.1841

# %% [markdown]
# ## Save training log

# %%
log_all      = pd.concat([log_p1, log_p2], ignore_index=True)
log_csv_path = LOGS_DIR / "model1_training_log.csv"
log_all.to_csv(log_csv_path, index=False)
print(f"\n[Log] Training log saved → {log_csv_path}")
# Out:
# [Log] Training log saved → /kaggle/working/training/logs/model1_training_log.csv

# %% [markdown]
# # Export model

# %%
torch.save(model.state_dict(), MODEL1_PATH)
print(f"[Done] Model state dict saved → {MODEL1_PATH}")

with open(label_map_path, "w") as f:
    json.dump(label_to_idx, f, indent=2)

print(f"[Done] Label map saved       → {label_map_path}")
# Out:
# [Done] Model state dict saved → /kaggle/working/models/model1_detector.pth
# [Done] Label map saved       → /kaggle/working/models/model1_label_map.json

# %% [markdown]
# # Quick inference check on one validation image

# %%
model.roi_heads.score_thresh = 0.20

# %%
model.eval()

sample_record = val_dataset.records[0]
sample_image, sample_target = val_dataset[0]

with torch.no_grad():
    prediction = model([sample_image.to(DEVICE)])[0]

print(f"\n[Inference check]")
print(f"  Image        : {sample_record['image_path']}")
print(f"  Ground truth : {sample_target['boxes'].tolist()}")
print(f"  Predicted boxes  : {prediction['boxes'].cpu().tolist()}")
print(f"  Predicted labels : {prediction['labels'].cpu().tolist()}")
print(f"  Predicted scores : {[f'{s:.3f}' for s in prediction['scores'].cpu().tolist()]}")

# Decode label indices back to names
idx_to_label = {v: k for k, v in label_to_idx.items()}
idx_to_label[0] = "background"
print(f"  Decoded labels   : "
      f"{[idx_to_label.get(l.item(), '?') for l in prediction['labels'].cpu()]}")

print("\n[Info] To evaluate with COCO mAP metrics, install pycocotools:")
print("       !pip install pycocotools")
print("       Then use torchvision.ops.box_iou and the COCO evaluator.")
print(f"[Info] Test split for held-out evaluation → {test_csv_path}")
# Out:
# [Inference check]
#   Image        : /kaggle/input/datasets/matarauj/project-gn-data/data/raw/20260316_175744.jpg
#   Ground truth : [[19.614849090576172, 2.370490550994873, 454.92156982421875, 334.2960205078125]]
#   Predicted boxes  : [[48.66305160522461, 3.632094621658325, 427.2979736328125, 326.7213134765625], [9.325955390930176, 0.0, 467.5124206542969, 381.5242004394531]]
#   Predicted labels : [1, 2]
#   Predicted scores : ['0.297', '0.240']
#   Decoded labels   : ['large_container', 'small_container']
#
# [Info] To evaluate with COCO mAP metrics, install pycocotools:
#        !pip install pycocotools
#        Then use torchvision.ops.box_iou and the COCO evaluator.
# [Info] Test split for held-out evaluation → /kaggle/working/training/logs/model1_test_split.csv

# %% [markdown]
# # Visualisation

# %%
# =============================================================================
# Visualisation — draw predicted and ground-truth boxes on validation images
# =============================================================================
# Add this as a new cell at the bottom of your Colab notebook.
# Run after the inference check cell.
#
# Controls:
#   SCORE_THRESHOLD  — only show predictions above this confidence score.
#                      Start at 0.05 (low, to see everything), raise it
#                      once the model improves (e.g. 0.5 in production).
#   NUM_IMAGES       — how many validation images to display.
# =============================================================================

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.patheffects as pe


# --- Settings ----------------------------------------------------------------

SCORE_THRESHOLD = 0.05   # lower = show more boxes; raise as model improves
NUM_IMAGES      = 4      # number of val images to display


# --- Colour map --------------------------------------------------------------
# Index 0 = background (never shown), 1 and 2 = your two container classes.
# Ground-truth boxes are drawn in a lighter tint of the same colour.

CLASS_COLOURS = {
    0: "#888888",   # background — not drawn
    1: "#E8593C",   # large_container  — coral/orange
    2: "#1D9E75",   # small_container  — teal/green
}


# --- Helper ------------------------------------------------------------------

def draw_boxes(ax, boxes, labels, scores=None, class_colours=CLASS_COLOURS,
               idx_to_label=None, is_gt=False):
    """
    Draw bounding boxes on a matplotlib Axes.

    Parameters
    ----------
    ax           : matplotlib Axes
    boxes        : list of [x_min, y_min, x_max, y_max]
    labels       : list of int (1-based class indices)
    scores       : list of float, or None (ground truth has no scores)
    class_colours: dict {label_idx: hex_colour}
    idx_to_label : dict {label_idx: label_name}
    is_gt        : bool — True draws dashed border (ground truth style)
    """
    for i, (box, label) in enumerate(zip(boxes, labels)):
        x_min, y_min, x_max, y_max = box
        w = x_max - x_min
        h = y_max - y_min

        colour    = class_colours.get(int(label), "#888888")
        linestyle = "--" if is_gt else "-"
        linewidth = 1.5 if is_gt else 2.0
        alpha     = 0.6 if is_gt else 0.9

        rect = patches.FancyBboxPatch(
            (x_min, y_min), w, h,
            boxstyle="square,pad=0",
            linewidth=linewidth,
            edgecolor=colour,
            facecolor="none",
            linestyle=linestyle,
            alpha=alpha,
        )
        ax.add_patch(rect)

        # Label text
        label_name = idx_to_label.get(int(label), str(label)) if idx_to_label else str(label)
        if is_gt:
            text = f"GT: {label_name}"
        elif scores is not None:
            text = f"{label_name} {scores[i]:.2f}"
        else:
            text = label_name

        txt = ax.text(
            x_min + 3, y_min + 3,
            text,
            fontsize=7,
            color="white",
            verticalalignment="top",
        )
        # Dark outline so text is readable on any background
        txt.set_path_effects([
            pe.Stroke(linewidth=2, foreground=colour),
            pe.Normal(),
        ])


# --- Main visualisation loop -------------------------------------------------

model.eval()

# Pick up to NUM_IMAGES images from the validation set
n_show  = min(NUM_IMAGES, len(val_dataset))
indices = list(range(n_show))

fig, axes = plt.subplots(
    n_show, 1,
    figsize=(10, 6 * n_show),
    squeeze=False,
)

for plot_idx, sample_idx in enumerate(indices):
    image_tensor, gt_target = val_dataset[sample_idx]
    record = val_dataset.records[sample_idx]

    # Run inference
    with torch.no_grad():
        predictions = model([image_tensor.to(DEVICE)])[0]

    # Convert image tensor [C, H, W] → numpy [H, W, C] for matplotlib
    img_np = image_tensor.permute(1, 2, 0).cpu().numpy()
    img_np = img_np.clip(0, 1)

    ax = axes[plot_idx][0]
    ax.imshow(img_np)
    ax.set_axis_off()

    filename = Path(record["image_path"]).name
    ax.set_title(
        f"{filename}",
        fontsize=9, pad=4, loc="left",
    )

    # Filter predictions by score threshold
    pred_boxes  = predictions["boxes"].cpu().tolist()
    pred_labels = predictions["labels"].cpu().tolist()
    pred_scores = predictions["scores"].cpu().tolist()

    keep = [i for i, s in enumerate(pred_scores) if s >= SCORE_THRESHOLD]
    pred_boxes_f  = [pred_boxes[i]  for i in keep]
    pred_labels_f = [pred_labels[i] for i in keep]
    pred_scores_f = [pred_scores[i] for i in keep]

    # Ground truth boxes
    gt_boxes  = gt_target["boxes"].tolist()
    gt_labels = gt_target["labels"].tolist()

    # Draw ground truth first (dashed), then predictions (solid) on top
    draw_boxes(ax, gt_boxes,      gt_labels,      scores=None,
               idx_to_label=idx_to_label, is_gt=True)
    draw_boxes(ax, pred_boxes_f,  pred_labels_f,  scores=pred_scores_f,
               idx_to_label=idx_to_label, is_gt=False)

    # Legend summary
    n_pred = len(pred_boxes_f)
    n_gt   = len(gt_boxes)
    ax.set_xlabel(
        f"Ground truth: {n_gt} box(es)   |   "
        f"Predicted (score ≥ {SCORE_THRESHOLD}): {n_pred} box(es)",
        fontsize=8, labelpad=4,
    )

plt.suptitle(
    f"Model #1 — Faster R-CNN predictions\n"
    f"Coral = large_container  |  Teal = small_container  |  "
    f"Dashed = ground truth  |  Solid = prediction",
    fontsize=9, y=1.002,
)
plt.tight_layout()
plt.show()

print(f"\nShowing {n_show} validation image(s).")
print(f"Score threshold: {SCORE_THRESHOLD}  "
      f"(raise this as training improves — use 0.4–0.6 in production)")
# Out:
# Showing 4 validation image(s).
# Score threshold: 0.05  (raise this as training improves — use 0.4–0.6 in production)
